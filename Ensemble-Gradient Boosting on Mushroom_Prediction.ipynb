# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Project Understanding :

# This project is about the prediction on the mushroom is good or poisonous, based on the various features of the mushroom.
# While buying mushroom customers will refers this model to identify eatable mushroom.


# Data Understanding :

df = pd.read_csv("mushrooms.csv")
print(df)
print("-"*100)

print(df.info())
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
print(df["class"].unique())
print(df["class"].value_counts())
print("-"*100)

print(df["cap-shape"].unique())
print(df["cap-shape"].value_counts())
print("-"*100)

print(df["cap-surface"].unique())
print(df["cap-surface"].value_counts())
print("-"*100)

print(df["cap-color"].unique())
print(df["cap-color"].value_counts())
print("-"*100)

print(df["bruises"].unique())
print(df["bruises"].value_counts())
print("-"*100)

print(df["odor"].unique())
print(df["odor"].value_counts())
print("-"*100)

print(df["gill-attachment"].unique())
print(df["gill-attachment"].value_counts())
print("-"*100)

print(df["gill-spacing"].unique())
print(df["gill-spacing"].value_counts())
print("-"*100)

print(df["gill-size"].unique())
print(df["gill-size"].value_counts())
print("-"*100)

print(df["gill-color"].unique())
print(df["gill-color"].value_counts())
print("-"*100)

print(df["stalk-shape"].unique())
print(df["stalk-shape"].value_counts())
print("-"*100)

print(df["stalk-root"].unique())
print(df["stalk-root"].value_counts())
print("-"*100)

print(df["stalk-surface-above-ring"].unique())
print(df["stalk-surface-above-ring"].value_counts())
print("-"*100)

print(df["stalk-surface-below-ring"].unique())
print(df["stalk-surface-below-ring"].value_counts())
print("-"*100)

print(df["stalk-color-above-ring"].unique())
print(df["stalk-color-above-ring"].value_counts())
print("-"*100)

print(df["stalk-color-below-ring"].unique())
print(df["stalk-color-below-ring"].value_counts())
print("-"*100)

print(df["veil-type"].unique())
print(df["veil-type"].value_counts())
print("-"*100)

print(df["veil-color"].unique())
print(df["veil-color"].value_counts())
print("-"*100)

print(df["ring-number"].unique())
print(df["ring-number"].value_counts())
print("-"*100)

print(df["ring-type"].unique())
print(df["ring-type"].value_counts())
print("-"*100)

print(df["spore-print-color"].unique())
print(df["spore-print-color"].value_counts())
print("-"*100)

print(df["population"].unique())
print(df["population"].value_counts())
print("-"*100)

print(df["habitat"].unique())
print(df["habitat"].value_counts())
print("-"*100)
# Out:
# ['p' 'e']
# class
# e    4208
# p    3916
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ['x' 'b' 's' 'f' 'k' 'c']
# cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ['s' 'y' 'f' 'g']
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ['t' 'f']
# bruises
# f    4748
# t    3376
# ...

# %%
# Data Preprocessing : 

# Data Cleaning :

# In this dataset wrong data, wrong data types are not there.

print(df.isnull().sum())         # No any null value is there
print("-"*100)
print(df.duplicated().sum())     # No any duplicates value is there
print("-"*100)

# Data Wrangling : 

# In this dataset we have all columns with discrete categorical values, so we have to do the encoding, we will use here dummy encoding
# Here more input columns are there for encoding comparatevely to the Penguine_Dataset, So we should not do the enconding with taking direct input columns names in get_dummies() function,
# we should do encoding by dropping output column directly, that will gives us all input columns and also takes comparitively less time.

df1 = pd.get_dummies(data = df.drop("class",axis=1),drop_first=True)
print(df1)
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
# 0
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# model(machine) can understand True & False from the encoding as the 1's and 0's internally, 
# So here is no need of converting True and False into the 1's and 0's resp.


X = df1    # or  pd.get_dummies(data = df.drop("class",axis=1),drop_first=True)
print(X)
print("-"*100)

y = df["class"]
print(y)
print("-"*100)


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=9)


# Modelling :  for default model  

from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train,y_train)


# Prediction :  for default model 

ypred_train = model.predict(X_train)
ypred_test = model.predict(X_test)


# Evaluation :  for default model

train_accuracy = model.score(X_train,y_train)
print("train_accuracy:",train_accuracy)
test_accuracy = model.score(X_test,y_test)
print("test_accuracy:",test_accuracy)

from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,X,y,cv=5)
print("cross_val_score:",scores.mean())
# Out:
#       cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  cap-shape_x  \
# 0           False        False        False        False         True
# 1           False        False        False        False         True
# 2           False        False        False        False        False
# 3           False        False        False        False         True
# 4           False        False        False        False         True
# ...           ...          ...          ...          ...          ...
# 8119        False        False         True        False        False
# 8120        False        False        False        False         True
# 8121        False         True        False        False        False
# 8122        False        False         True        False        False
# 8123        False        False        False        False         True
#
#       cap-surface_g  cap-surface_s  cap-surface_y  cap-color_c  cap-color_e  \
# ...

# %%
# We have to identify the best Hypeparameters and important columns from datset for best AdaBoost model 

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import GradientBoostingClassifier
estimator = GradientBoostingClassifier()

grid_param = {"n_estimators":list(range(1,5)),"learning_rate":[0.1,0.2,0.3,0.5,0.7,1.0]}
gb_classifier = GridSearchCV(estimator,grid_param,cv=5,scoring="accuracy")

gb_classifier.fit(X_train,y_train)
gb_classifier.best_params_
# Out:
# {'learning_rate': 0.7, 'n_estimators': 4}

# %%
gb_classifier.best_estimator_.feature_importances_
# Out:
# array([0.00000000e+00, 2.21081773e-17, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.54149331e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.24702872e-03, 3.29410672e-02, 0.00000000e+00, 4.12326475e-03,
#        0.00000000e+00, 0.00000000e+00, 6.18267632e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.21009636e-02,
#        4.80051100e-03, 0.00000000e+00, 3.52534035e-16, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.42134589e-17, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.69426414e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.08264992e-01, 0.00000000e+00,
# ...

# %%
feats = pd.DataFrame(data = gb_classifier.best_estimator_.feature_importances_,
                    index = X.columns,
                    columns = ["Important Features"])
print(feats)
print("-"*100)

imp_feats = feats[feats["Important Features"]>0]
print(imp_feats)

imp_feats_list = imp_feats.index.tolist()      #  or list(imp_feats)  it will also give same output(answer)
# Out:
#              Important Features
# cap-shape_c        0.000000e+00
# cap-shape_f        2.210818e-17
# cap-shape_k        0.000000e+00
# cap-shape_s        0.000000e+00
# cap-shape_x        0.000000e+00
# ...                         ...
# habitat_l          0.000000e+00
# habitat_m          0.000000e+00
# habitat_p          0.000000e+00
# habitat_u          0.000000e+00
# habitat_w          0.000000e+00
#
# [95 rows x 1 columns]
# ----------------------------------------------------------------------------------------------------
#                             Important Features
# cap-shape_f                       2.210818e-17
# cap-surface_g                     1.541493e-03
# cap-color_y                       1.247029e-03
# bruises_t                         3.294107e-02
# odor_f                            4.123265e-03
# odor_n                            6.182676e-01
# gill-spacing_w                    2.210096e-02
# gill-size_n                       4.800511e-03
# ...

# %%
X_new = X[imp_feats_list]
print(X_new)
print("-"*100)

y = df["class"]   # y will be as it is (same as old y)


# For best final model we have to do again train_test_split, modelling, prediction, evaluation with the identified best Hyperparameter and important features

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=6)


# Modelling : with best Hyperparameter and Important Features 

from sklearn.ensemble import GradientBoostingClassifier
final_model = GradientBoostingClassifier()
final_model.fit(X_train,y_train)


# Prediction :  with best Hyperparameter and Important Features

ypred_train = final_model.predict(X_train)
ypred_test = final_model.predict(X_test)


# Evaluation :  with best Hyperparameter and Important Features

train_accuracy = final_model.score(X_train,y_train)
print("train_accuracy:",train_accuracy)
test_accuracy = final_model.score(X_test,y_test)
print("test_accuracy:",test_accuracy)

from sklearn.model_selection import cross_val_score
scores = cross_val_score(final_model,X,y,cv=5)
print("cross_val_score:",scores.mean())
# Out:
#       cap-shape_f  cap-surface_g  cap-color_y  bruises_t  odor_f  odor_n  \
# 0           False          False        False       True   False   False
# 1           False          False         True       True   False   False
# 2           False          False        False       True   False   False
# 3           False          False        False       True   False   False
# 4           False          False        False      False   False    True
# ...           ...            ...          ...        ...     ...     ...
# 8119        False          False        False      False   False    True
# 8120        False          False        False      False   False    True
# 8121         True          False        False      False   False    True
# 8122        False          False        False      False   False   False
# 8123        False          False        False      False   False    True
#
#       gill-spacing_w  gill-size_n  gill-color_g  gill-color_w  stalk-root_c  \
# ...
